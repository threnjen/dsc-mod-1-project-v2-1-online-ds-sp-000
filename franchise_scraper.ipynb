# %% [markdown]
# # Overview
#
# This get_franchises loads the TMDB data file with IMDB IDs, containing 10,000 movie entries, and scrapes the Box Office Mojo website for any/all of the following:
#     * budget
#     * domestic gross
#     * worldwide gross
#     * studio
#     * MPAA rating

# %% [markdown]
# # Library Imports

# %%
import pandas as pd
import requests
import re
import numpy as np
from bs4 import BeautifulSoup as bs
import time
from random import randint
from time import sleep
from fake_useragent import UserAgent

# %%
ua = UserAgent()
header = {'User-Agent':str(ua.random)}
print(header)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36'}

# %% [markdown]
# # Scraping Functions

# %%
#function that goes to the base page and grabs the content
def get_franchises():
    followurl = 'https://www.the-numbers.com/movies/franchises'
    page = requests.get(followurl, headers=header)
    soup = bs(page.content, 'html.parser')
    franchise_links(soup)

# %%
# function that collects the franchise links from the base page and puts them in our list of tags to follow

def franchise_links(soup):
    for link in soup.find_all('a', href=True):
        if '/movies/franchise/' in link.get('href'):
            franchise = link.text # saving the franchise name here in a variable. We need to figure out where to properly connect this
            franchiselinks[franchise] = link.get('href')
        else: continue

# %%
# follows a link from the base page
def grab_next(franchise_link):
    followurl = 'https://www.the-numbers.com' + franchise_link
    page = requests.get(followurl, headers=header)
    soup = bs(page.content, 'html.parser')
    return soup

# %%
def scraper(links, enddict):
    count = 1
    length = len(links)
    ts = time.time()
    
    for key, value in links.items():
        print(('Item {} / {} - {}').format(count, length, key))
        
        soup = grab_next(value)
        franchise_table = soup.find('table', id="franchise_movies_overview")
        entries = franchise_table.find_all('a', href=True)
        for item in entries:
            enddict['franchise'].append(key)
            enddict['movie'].append(item.text)
        
        sleep(randint(0,2))
        count += 1
    tnow = time.time()
    duration = round((tnow - ts), 2)
    scrape_average = round(duration/length, 2)
    print('{} minutes elapsed'.format(duration/60))
    print('{} seconds per item'.format(scrape_average))
    return enddict

# %% [markdown]
# get_franchises in plain english
#
#     * make an empty list for all of the franchise page appendations
#     * get the base page with the base get_franchises
#     * grab all of the appendations and store them in a list
#     * For each item in the list follow it to the franchise page
#     * from teh franchise page, grab the franchise and the movie name and put it in the dataframe
#     * clean up the movie names with our cleanup function

# %% [markdown]
# # Testing Set
#
# Before we scrape for 10k returns, we will do a small test scrape

# %%
franchiselinks = {}

# %%
tempset = {'franchise' : [], 'movie' : []}

# %%
get_franchises()

# %%
franchiselinks
# Out:
# {'Marvel Cinematic Universe': '/movies/franchise/Marvel-Cinematic-Universe',
#  'Star Wars': '/movies/franchise/Star-Wars',
#  'James Bond': '/movies/franchise/James-Bond',
#  'Batman': '/movies/franchise/Batman',
#  'Harry Potter': '/movies/franchise/Harry-Potter',
#  'Spider-Man': '/movies/franchise/Spider-Man',
#  'X-Men': '/movies/franchise/X-Men',
#  'Avengers': '/movies/franchise/Avengers',
#  'Jurassic Park': '/movies/franchise/Jurassic-Park',
#  'Star Trek': '/movies/franchise/Star-Trek',
#  "Peter Jackson's Lord of the Rings": '/movies/franchise/Peter-Jacksons-Lord-of-the-Rings',
#  'DC Extended Universe': '/movies/franchise/DC-Extended-Universe',
#  'Indiana Jones': '/movies/franchise/Indiana-Jones',
#  'Superman': '/movies/franchise/Superman',
#  'Fast and the Furious': '/movies/franchise/Fast-and-the-Furious',
#  'Shrek': '/movies/franchise/Shrek',
#  'Rocky': '/movies/franchise/Rocky',
#  'Pirates of the Caribbean': '/movies/franchise/Pirates-of-the-Caribbean',
#  'Transformers': '/movies/franchise/Transformers',
#  'Toy Story': '/movies/franchise/Toy-Story',
#  'Jaws': '/movies/franchise/Jaws',
#  'Hunger Games': '/movies/franchise/Hunger-Games',
#  'Twilight': '/movies/franchise/Twilight',
#  'Mission: Impossible': '/movies/franchise/Mission-Impossible',
#  'Dark Knight Trilogy': '/movies/franchise/Dark-Knight-Trilogy',
#  'Peter Pan': '/movies/franchise/Peter-Pan',
#  'Planet of the Apes': '/movies/franchise/Planet-of-the-Apes',
#  'The Lion King': '/movies/franchise/Lion-King-The',
#  'Despicable Me': '/movies/franchise/Despicable-Me',
#  'Lady and the Tramp': '/movies/franchise/Lady-and-the-Tramp',
#  'Exorcist': '/movies/franchise/Exorcist',
#  'Billy Jack': '/movies/franchise/Billy-Jack',
#  'Iron Man': '/movies/franchise/Iron-Man',
#  'Mary Poppins': '/movies/franchise/Mary-Poppins',
#  'King Kong': '/movies/franchise/King-Kong',
#  'Alien': '/movies/franchise/Alien',
#  'Men in Black': '/movies/franchise/Men-in-Black',
#  'Terminator': '/movies/franchise/Terminator',
#  'Finding Nemo': '/movies/franchise/Finding-Nemo',
#  'Beverly Hills Cop': '/movies/franchise/Beverly-Hills-Cop',
#  'Home Alone': '/movies/franchise/Home-Alone',
#  'Lethal Weapon': '/movies/franchise/Lethal-Weapon',
#  'Bourne': '/movies/franchise/Bourne',
#  'Ice Age': '/movies/franchise/Ice-Age',
#  'Ghostbusters': '/movies/franchise/Ghostbusters',
#  'Cinderella': '/movies/franchise/Cinderella',
#  'The Incredibles': '/movies/franchise/Incredibles-The',
#  'Airport': '/movies/franchise/Airport',
#  'Back to the Future': '/movies/franchise/Back-to-the-Future',
#  'Jumanji': '/movies/franchise/Jumanji',
#  'Jack Ryan': '/movies/franchise/Jack-Ryan',
#  'Matrix': '/movies/franchise/Matrix',
#  'Teenage Mutant Ninja Turtles': '/movies/franchise/Teenage-Mutant-Ninja-Turtles',
#  'Frozen': '/movies/franchise/Frozen',
#  'Jungle Book': '/movies/franchise/Jungle-Book',
#  'Captain America': '/movies/franchise/Captain-America',
#  'The Hobbit': '/movies/franchise/Hobbit-The',
#  'Avatar': '/movies/franchise/Avatar',
#  'Pink Panther': '/movies/franchise/Pink-Panther',
#  'Die Hard': '/movies/franchise/Die-Hard',
#  'Mummy': '/movies/franchise/Mummy',
#  'Dirty Harry': '/movies/franchise/Dirty-Harry',
#  'Meet the Parents': '/movies/franchise/Meet-the-Parents',
#  'Friday the 13th': '/movies/franchise/Friday-the-13th',
#  'Madagascar': '/movies/franchise/Madagascar',
#  'National Lampoon': '/movies/franchise/National-Lampoon',
#  'Karate Kid': '/movies/franchise/Karate-Kid',
#  'The Sting': '/movies/franchise/Sting-The',
#  'Rush Hour': '/movies/franchise/Rush-Hour',
#  'Wizard of Oz': '/movies/franchise/Wizard-of-Oz',
#  'Austin Powers': '/movies/franchise/Austin-Powers',
#  'Around the World in 80 Days': '/movies/franchise/Around-the-World-in-80-Days',
#  'Alvin and the Chipmunks': '/movies/franchise/Alvin-and-the-Chipmunks',
#  "Ocean's Eleven": '/movies/franchise/Oceans-Eleven',
#  'Muppets': '/movies/franchise/Muppets',
#  'Guardians of the Galaxy': '/movies/franchise/Guardians-of-the-Galaxy',
#  'Smokey and the Bandit': '/movies/franchise/Smokey-and-the-Bandit',
#  'Thor': '/movies/franchise/Thor',
#  'Hangover': '/movies/franchise/Hangover',
#  'Saturday Night Fever': '/movies/franchise/Saturday-Night-Fever',
#  'Hannibal Lecter': '/movies/franchise/Hannibal-Lecter',
#  'Monsters, Inc.': '/movies/franchise/Monsters-Inc',
#  'Rambo': '/movies/franchise/Rambo',
#  'Herbie': '/movies/franchise/Herbie',
#  'Independence Day': '/movies/franchise/Independence-Day',
#  'Cars': '/movies/franchise/Cars',
#  'Chronicles of Narnia': '/movies/franchise/Chronicles-of-Narnia',
#  'Godfather': '/movies/franchise/Godfather',
#  'Scary Movie': '/movies/franchise/Scary-Movie',
#  'Crocodile Dundee': '/movies/franchise/Crocodile-Dundee',
#  'Deadpool': '/movies/franchise/Deadpool',
#  'The Conjuring': '/movies/franchise/Conjuring-The',
#  'Halloween': '/movies/franchise/Halloween',
#  'Nightmare on Elm Street': '/movies/franchise/Nightmare-on-Elm-Street',
#  'Grease': '/movies/franchise/Grease',
#  'Fantasia': '/movies/franchise/Fantasia',
#  'Hulk': '/movies/franchise/Hulk',
#  'Night at the Museum': '/movies/franchise/Night-at-the-Museum',
#  'Santa Clause': '/movies/franchise/Santa-Clause',
#  'Butch Cassidy and the Sundance Kid': '/movies/franchise/Butch-Cassidy-and-the-Sundance-Kid',
#  'Madea': '/movies/franchise/Madea',
#  'Every Which Way But Loose': '/movies/franchise/Every-Which-Why-But-Loose',
#  'American Pie': '/movies/franchise/American-Pie',
#  'Lego': '/movies/franchise/Lego',
#  'Godzilla': '/movies/franchise/Godzilla',
#  'American Graffiti': '/movies/franchise/American-Graffiti',
#  'Kung Fu Panda': '/movies/franchise/Kung-Fu-Panda',
#  'How to Train Your Dragon': '/movies/franchise/How-to-Train-Your-Dragon',
#  'Police Academy': '/movies/franchise/Police-Academy',
#  'Scream': '/movies/franchise/Scream',
#  "National Lampoon's Vacation": '/movies/franchise/National-Lampoons-Vacation',
#  'Saw': '/movies/franchise/Saw',
#  'Wolverine': '/movies/franchise/Wolverine',
#  'Bad Boys': '/movies/franchise/Bad-Boys',
#  'Psycho': '/movies/franchise/Psycho',
#  'The Secret Life of Pets': '/movies/franchise/Secret-Life-of-Pets-The',
#  'Cheech & Chong': '/movies/franchise/Cheech-and-Chong',
#  'It': '/movies/franchise/It',
#  'National Treasure': '/movies/franchise/National-Treasure',
#  'Three Men and a Baby': '/movies/franchise/Three-Men-and-a-Baby',
#  'Spy Kids': '/movies/franchise/Spy-Kids',
#  'Hotel Transylvania': '/movies/franchise/Hotel-Transylvania',
#  'Fugitive': '/movies/franchise/Fugitive',
#  '2001': '/movies/franchise/2001',
#  'MonsterVerse': '/movies/franchise/MonsterVerse',
#  'Da Vinci Code': '/movies/franchise/Da-Vinci-Code',
#  'Bruce Almighty': '/movies/franchise/Bruce-Almighty',
#  'Gremlins': '/movies/franchise/Gremlins',
#  "Porky's": '/movies/franchise/Porkys',
#  'Predator': '/movies/franchise/Predator',
#  'Naked Gun': '/movies/franchise/Naked-Gun',
#  'Nutty Professor': '/movies/franchise/Nutty-Professor',
#  'Alice in Wonderland': '/movies/franchise/Alice-in-Wonderland',
#  'Paranormal Activity': '/movies/franchise/Paranormal-Activity',
#  'Sherlock Holmes': '/movies/franchise/Sherlock-Holmes',
#  'Doctor Dolittle': '/movies/franchise/Doctor-Dolittle',
#  'Amityville': '/movies/franchise/Amityville',
#  'Fantastic Four': '/movies/franchise/Fantastic-Four',
#  'Jackass': '/movies/franchise/Jackass',
#  'My Big Fat Greek Wedding': '/movies/franchise/My-Big-Fat-Greek-Wedding',
#  "Look Who's Talking": '/movies/franchise/Look-Whos-Talking',
#  'Top Gun': '/movies/franchise/Top-Gun',
#  'Sister Act': '/movies/franchise/Sister-Act',
#  'Taken': '/movies/franchise/Taken',
#  'Honey I Shrunk the Kids': '/movies/franchise/Honey-I-Shrunk-the-Kids',
#  'Wonder Woman': '/movies/franchise/Wonder-Woman',
#  'Wreck-It Ralph': '/movies/franchise/Wreck-It-Ralph',
#  'Unbreakable': '/movies/franchise/Unbreakable',
#  'Ant-Man': '/movies/franchise/Ant-Man',
#  'Dumb and Dumber': '/movies/franchise/Dumb-and-Dumber',
#  'Guns of Navarone': '/movies/franchise/Guns-of-Navarone',
#  'Fantastic Beasts and Where to Find Them': '/movies/franchise/Fantastic-Beasts-and-Where-to-Find-Them',
#  'Pokemon': '/movies/franchise/Pokemon',
#  '300': '/movies/franchise/300',
#  '48 Hrs.': '/movies/franchise/48-Hrs',
#  'Fifty Shades of Grey': '/movies/franchise/Fifty-Shades-of-Grey',
#  '101 Dalmatians': '/movies/franchise/101-Dalmatians',
#  'Ace Ventura': '/movies/franchise/Ace-Ventura',
#  'Beauty and the Beast': '/movies/franchise/Beauty-and-the-Beast',
#  'Maleficent': '/movies/franchise/Maleficent',
#  'Rugrats Movie': '/movies/franchise/Rugrats',
#  "Charlie's Angels": '/movies/franchise/Charlies-Angels',
#  'Pitch Perfect': '/movies/franchise/Pitch-Perfect',
#  'The Divergent Series': '/movies/franchise/Divergent-Series-The',
#  'Texas Chainsaw Massacre': '/movies/franchise/Texas-Chainsaw-Massacre',
#  'Romancing the Stone': '/movies/franchise/Romancing-the-Stone',
#  "Wayne's World": '/movies/franchise/Waynes-World',
#  '21 Jump Street': '/movies/franchise/21-Jump-Street',
#  'Lara Croft': '/movies/franchise/Lara-Croft',
#  'Omen': '/movies/franchise/Omen',
#  'Speed': '/movies/franchise/Speed',
#  'Final Destination': '/movies/franchise/Final-Destination',
#  'City Slickers': '/movies/franchise/City-Slickers',
#  'Mad Max': '/movies/franchise/Mad-Max',
#  'Scooby-Doo': '/movies/franchise/Scooby-Doo',
#  'Poltergeist': '/movies/franchise/Poltergeist',
#  'Minions': '/movies/franchise/Minions',
#  'Airplane': '/movies/franchise/Airplane',
#  'Father of the Bride': '/movies/franchise/Father-of-the-Bride',
#  'Flintstones': '/movies/franchise/Flintstones',
#  'Resident Evil': '/movies/franchise/Resident-Evil',
#  'Man of Steel': '/movies/franchise/Man-of-Steel',
#  'Addams Family': '/movies/franchise/Addams-Family',
#  'Stuart Little': '/movies/franchise/Stuart-Little',
#  'Odd Couple': '/movies/franchise/Odd-Couple',
#  'Blade': '/movies/franchise/Blade',
#  "Big Momma's House": '/movies/franchise/Big-Mommas-House',
#  'Ring': '/movies/franchise/Ring',
#  'Ted': '/movies/franchise/Ted',
#  'Grown Ups': '/movies/franchise/Grown-Ups',
#  'Terms of Endearment': '/movies/franchise/Terms-of-Endearment',
#  'Cheaper by the Dozen': '/movies/franchise/Cheaper-by-the-Dozen',
#  'Underworld': '/movies/franchise/Underworld',
#  'G.I. Joe': '/movies/franchise/G-I-Joe',
#  'Blair Witch Project': '/movies/franchise/Blair-Witch-Project',
#  'Oh, God!': '/movies/franchise/Oh-God',
#  'Princess Diaries': '/movies/franchise/Princess-Diaries',
#  'John Wick': '/movies/franchise/John-Wick',
#  'Rio': '/movies/franchise/Rio',
#  'Benji': '/movies/franchise/Benji',
#  'xXx': '/movies/franchise/xXx',
#  'SpongeBob SquarePants': '/movies/franchise/SpongeBob-SquarePants',
#  'The Purge': '/movies/franchise/Purge-The',
#  'Grumpy Old Men': '/movies/franchise/Grumpy-Old-Men',
#  'Sex and the City': '/movies/franchise/Sex-and-the-City',
#  'Mamma Mia': '/movies/franchise/Mamma-Mia',
#  'Arthur': '/movies/franchise/Arthur',
#  'Legally Blonde': '/movies/franchise/Legally-Blonde',
#  'Mask': '/movies/franchise/Mask',
#  'Hancock': '/movies/franchise/Hancock',
#  'The Smurfs': '/movies/franchise/Smurfs-The',
#  'Under Siege': '/movies/franchise/Under-Siege',
#  'Cloudy with a Chance of Meatballs': '/movies/franchise/Cloudy-with-a-Chance-of-Meatballs',
#  'Clash of the Titans': '/movies/franchise/Clash-of-the-Titans',
#  'Tron': '/movies/franchise/Tron',
#  'French Connection': '/movies/franchise/French-Connection',
#  "Child's Play": '/movies/franchise/Childs-Play',
#  'Insidious': '/movies/franchise/Insidious',
#  'Annabelle': '/movies/franchise/Annabelle',
#  'Barbershop': '/movies/franchise/Barbershop',
#  'Step Up': '/movies/franchise/Step-Up',
#  'Basic Instinct': '/movies/franchise/Basic-Instinct',
#  'Daddyâ\x80\x99s Home': '/movies/franchise/Daddys-Home',
#  'Anchorman': '/movies/franchise/Anchorman',
#  'Cannonball Run': '/movies/franchise/Cannonball-Run',
#  'Elf': '/movies/franchise/Elf',
#  'Shaft': '/movies/franchise/Shaft',
#  'The Maze Runner': '/movies/franchise/Maze-Runner-The',
#  'Mighty Ducks': '/movies/franchise/Mighty-Ducks',
#  'The Expendables': '/movies/franchise/Expendables-The',
#  'Paul Blart: Mall Cop': '/movies/franchise/Paul-Blart-Mall-Cop',
#  'Journey to the Center of the Earth': '/movies/franchise/Journey-to-the-Center-of-the-Earth',
#  'Zorro': '/movies/franchise/Zorro',
#  'RoboCop': '/movies/franchise/RoboCop',
#  'Fallen': '/movies/franchise/Fallen',
#  'Ride Along': '/movies/franchise/Ride-Along',
#  'Miss Congeniality': '/movies/franchise/Miss-Congeniality',
#  'Analyze This': '/movies/franchise/Analyze-This',
#  'The Little Mermaid': '/movies/franchise/Little-Mermaid-The',
#  'Beethoven': '/movies/franchise/Beethoven',
#  'Free Willy': '/movies/franchise/Free-Willy',
#  'Kingsman': '/movies/franchise/Kingsman',
#  'Cocoon': '/movies/franchise/Cocoon',
#  'Grudge': '/movies/franchise/Grudge',
#  'Bad News Bears': '/movies/franchise/Bad-News-Bears',
#  'Mulan': '/movies/franchise/Mulan',
#  'Hot Shots': '/movies/franchise/Hot-Shots',
#  'Get Shorty': '/movies/franchise/Get-Shorty',
#  'Lilo and Stitch': '/movies/franchise/Lilo-and-Stitch',
#  'Snow White and the Huntsman': '/movies/franchise/Snow-White-and-the-Huntsman',
#  'Flint': '/movies/franchise/Flint',
#  'Eddie Felson': '/movies/franchise/Eddie-Felson',
#  'World War Z': '/movies/franchise/World-War-Z',
#  'Neighbors': '/movies/franchise/Neighbors',
#  "Garry Marshall's Holiday Franchise": '/movies/franchise/Garry-Marshall-s-Holiday-Franchise',
#  'Road To â\x80¦': '/movies/franchise/Road-To',
#  'Pet Sematary': '/movies/franchise/Pet-Sematary',
#  'Thomas Crown Affair': '/movies/franchise/Thomas-Crown-Affair',
#  'Blues Brothers': '/movies/franchise/Blues-Brothers',
#  'I Know What You Did Last Summer': '/movies/franchise/I-Know-What-You-Did-Last-Summer',
#  'Mortal Kombat': '/movies/franchise/Mortal-Kombat',
#  'Death Wish': '/movies/franchise/Death-Wish',
#  'The Equalizer': '/movies/franchise/Equalizer-The',
#  'Conan': '/movies/franchise/Conan',
#  'The Red Curtain Trilogy': '/movies/franchise/Red-Curtain-Trilogy-The',
#  'Sonyâ\x80\x99s Marvel Universe': '/movies/franchise/Sonys-Marvel-Universe',
#  'Ghost Rider': '/movies/franchise/Ghost-Rider',
#  'Diary of a Wimpy Kid': '/movies/franchise/Diary-of-a-Wimpy-Kid',
#  'The Croods': '/movies/franchise/Croods-The',
#  'Crouching Tiger, Hidden Dragon': '/movies/franchise/Crouching-Tiger-Hidden-Dragon',
#  'The Hunchback of Notre Dame': '/movies/franchise/Hunchback-of-Notre-Dame-The',
#  'Friday': '/movies/franchise/Friday',
#  'Hellboy': '/movies/franchise/Hellboy',
#  'Ernest': '/movies/franchise/Ernest',
#  'Kill Bill': '/movies/franchise/Kill-Bill',
#  'Magic Mike': '/movies/franchise/Magic-Mike',
#  'Cats and Dogs': '/movies/franchise/Cats-and-Dogs',
#  'Now You See Me': '/movies/franchise/Now-You-See-Me',
#  'Bridget Jones': '/movies/franchise/Bridget-Jones',
#  'Riddick': '/movies/franchise/Riddick',
#  'Kindergarten Cop': '/movies/franchise/Kindergarten-Cop',
#  'Stakeout': '/movies/franchise/Stakeout',
#  'Fletch': '/movies/franchise/Fletch',
#  'Horrible Bosses': '/movies/franchise/Horrible-Bosses',
#  'Young Guns': '/movies/franchise/Young-Guns',
#  'Bad Moms': '/movies/franchise/Bad-Moms',
#  'Purple Rain': '/movies/franchise/Purple-Rain',
#  'X-Files': '/movies/franchise/X-Files',
#  'Blade Runner': '/movies/franchise/Blade-Runner',
#  'Major League': '/movies/franchise/Major-League',
#  'A Quiet Place': '/movies/franchise/Quiet-Place-A',
#  'Shanghai Noon': '/movies/franchise/Shanghai-Noon',
#  'Space Jam': '/movies/franchise/Space-Jam',
#  'Are We There Yet?': '/movies/franchise/Are-We-There-Yet',
#  'The Shining': '/movies/franchise/Shining-The',
#  'Percy Jackson': '/movies/franchise/Percy-Jackson',
#  'The Heat': '/movies/franchise/Heat-The',
#  'The Boss Baby': '/movies/franchise/Boss-Baby-The',
#  'Untouchables': '/movies/franchise/Untouchables',
#  'Cloverfield': '/movies/franchise/Cloverfield',
#  'Think Like a Man': '/movies/franchise/Think-Like-a-Man',
#  'Bill & Ted': '/movies/franchise/Bill-and-Ted',
#  'Anaconda': '/movies/franchise/Anaconda',
#  'View Askewniverse': '/movies/franchise/View-Askewniverse',
#  'Meatballs': '/movies/franchise/Meatballs',
#  'Daddy Day Care': '/movies/franchise/Daddy-Day-Care',
#  'Pacific Rim': '/movies/franchise/Pacific-Rim',
#  'AVP': '/movies/franchise/AVP',
#  'Problem Child': '/movies/franchise/Problem-Child',
#  'Backdraft': '/movies/franchise/Backdraft',
#  'Babe': '/movies/franchise/Babe',
#  'Dirty Dancing': '/movies/franchise/Dirty-Dancing',
#  'Planes': '/movies/franchise/Planes',
#  'Power Rangers': '/movies/franchise/Power-Rangers',
#  'Black Stallion': '/movies/franchise/Black-Stallion',
#  'Knives Out': '/movies/franchise/Knives-Out',
#  'Zombieland': '/movies/franchise/Zombieland',
#  'RED': '/movies/franchise/RED',
#  'Revenge of the Nerds': '/movies/franchise/Revenge-of-the-Nerds',
#  'Species': '/movies/franchise/Species',
#  'My Girl': '/movies/franchise/My-Girl',
#  'Trolls': '/movies/franchise/Trolls',
#  'Wall Street': '/movies/franchise/Wall-Street',
#  'Caddyshack': '/movies/franchise/Caddyshack',
#  'Italian Job': '/movies/franchise/Italian-Job',
#  'American Tail': '/movies/franchise/American-Tail',
#  'Homeward Bound': '/movies/franchise/Homeward-Bound',
#  'A Fish Called Wanda': '/movies/franchise/Fish-Called-Wanda-A',
#  'Transporter': '/movies/franchise/Transporter',
#  'Gnomeo and Juliet': '/movies/franchise/Gnomeo-and-Juliet',
#  'American Werewolf': '/movies/franchise/American-Werewolf',
#  'The Angry Birds Movie': '/movies/franchise/Angry-Birds-Movie-The',
#  'Jack Reacher': '/movies/franchise/Jack-Reacher',
#  'Garfield': '/movies/franchise/Garfield',
#  'Crow': '/movies/franchise/Crow',
#  'Flatliners': '/movies/franchise/Flatliners',
#  'Peanuts': '/movies/franchise/Peanuts',
#  'Deuce Bigelow': '/movies/franchise/Deuce-Bigelow',
#  'Save the Last Dance': '/movies/franchise/Save-the-Last-Dance',
#  'Short Circuit': '/movies/franchise/Short-Circuit',
#  'Sonic The Hedgehog': '/movies/franchise/Sonic-The-Hedgehog',
#  'Safe House': '/movies/franchise/Safe-House',
#  'The Fox and the Hound': '/movies/franchise/The-Fox-and-the-Hound',
#  'El Mariachi': '/movies/franchise/El-Mariachi',
#  'Carrie': '/movies/franchise/Carrie',
#  'Why Did I Get Married': '/movies/franchise/Why-Did-I-Get-Married',
#  'Scorpion King': '/movies/franchise/Scorpion-King-',
#  'House Party': '/movies/franchise/House-Party',
#  'Brady Bunch': '/movies/franchise/Brady-Bunch',
#  'Ripley': '/movies/franchise/Ripley',
#  'The Best Man': '/movies/franchise/Best-Man-The',
#  'Chinatown': '/movies/franchise/Chinatown',
#  'Pee Wee': '/movies/franchise/Pee-Wee',
#  "Breakin'": '/movies/franchise/Breakin',
#  'Winnie the Pooh': '/movies/franchise/Winnie-the-Pooh',
#  'Fly': '/movies/franchise/Fly',
#  'Salt': '/movies/franchise/Salt',
#  'Escape from New York': '/movies/franchise/Escape-From-New-York',
#  'Bean': '/movies/franchise/Bean',
#  'Unbroken': '/movies/franchise/Unbroken',
#  'Goosebumps': '/movies/franchise/Goosebumps',
#  'Millennium (English)': '/movies/franchise/Millennium-(English)',
#  'Deep Blue Sea': '/movies/franchise/Deep-Blue-Sea',
#  'Dolphin Tale': '/movies/franchise/Dolphin-Tale',
#  'Brother Bear': '/movies/franchise/Brother-Bear',
#  'Mean Girls': '/movies/franchise/Mean-Girls',
#  'Jingle All the Way': '/movies/franchise/Jingle-All-the-Way',
#  'Inside Man': '/movies/franchise/Inside-Man',
#  'Paddington': '/movies/franchise/Paddington',
#  'Dark Crystal': '/movies/franchise/Dark-Crystal',
#  'Whole Nine Yards': '/movies/franchise/Whole-Nine-Yards',
#  'Sin City': '/movies/franchise/Sin-City',
#  'Beverly Hills Chihuahua': '/movies/franchise/Beverly-Hills-Chihuahua',
#  'Open Season': '/movies/franchise/Open-Season',
#  'Last Picture Show': '/movies/franchise/Last-Picture-Show',
#  'Un homme et une femme': '/movies/franchise/Un-homme-et-une-femme',
#  'Jeepers Creepers': '/movies/franchise/Jeepers-Creepers',
#  'Road Trip': '/movies/franchise/Road-Trip',
#  'Yogi Bear': '/movies/franchise/Yogi-Bear',
#  'Bring It On': '/movies/franchise/Bring-It-On',
#  'Harold & Kumar': '/movies/franchise/Harold-and-Kumar',
#  'High School Musical': '/movies/franchise/High-School-Musical',
#  'Dumbo': '/movies/franchise/Dumbo',
#  'Bad Grandpa': '/movies/franchise/Bad-Grandpa',
#  'Dukes of Hazzard': '/movies/franchise/Dukes-of-Hazzard',
#  'Old School': '/movies/franchise/Old-School',
#  'Sisterhood of the Traveling Pants': '/movies/franchise/Sisterhood-of-the-Traveling-Pants',
#  'Urban Legend': '/movies/franchise/Urban-Legend',
#  'Bad Santa': '/movies/franchise/Bad-Santa',
#  'Starship Troopers': '/movies/franchise/Starship-Troopers',
#  'The Land Before Time': '/movies/franchise/Land-Before-Time-The',
#  'Evil Dead': '/movies/franchise/Evil-Dead',
#  'Hellraiser': '/movies/franchise/Hellraiser',
#  'Agent Cody Banks': '/movies/franchise/Agent-Cody-Banks',
#  '28 Days Later': '/movies/franchise/28-Days-Later',
#  'Dragonheart': '/movies/franchise/Dragonheart',
#  'Dollar Trilogy': '/movies/franchise/Dollar-Trilogy',
#  "Kenneth Branagh's Hercule Poirot": '/movies/franchise/Kenneth-Branagh-s-Hercule-Poirot',
#  'Teen Wolf': '/movies/franchise/Teen-Wolf',
#  'Zoolander': '/movies/franchise/Zoolander',
#  'Missing in Action': '/movies/franchise/Missing-in-Action',
#  'Jumper': '/movies/franchise/Jumper',
#  'Sicario': '/movies/franchise/Sicario',
#  'The Nut Job': '/movies/franchise/Nut-Job-The',
#  'Nanny McPhee': '/movies/franchise/Nanny-McPhee',
#  'Universal Soldier': '/movies/franchise/Universal-Soldier',
#  "Weekend at Bernie's": '/movies/franchise/Weekend-at-Bernies',
#  'Downton Abbey': '/movies/franchise/Downton-Abbey',
#  'F/X': '/movies/franchise/FX',
#  'Mannequin': '/movies/franchise/Mannequin',
#  'Highlander': '/movies/franchise/Highlander',
#  "God's Not Dead": '/movies/franchise/God-s-Not-Dead',
#  'NeverEnding Story': '/movies/franchise/NeverEnding-Story',
#  'Creepshow': '/movies/franchise/Creepshow',
#  'White Fang': '/movies/franchise/White-Fang',
#  'Behind Enemy Lines': '/movies/franchise/Behind-Enemy-Lines',
#  'I Can Only Imagine': '/movies/franchise/I-Can-Only-Imagine',
#  'Ouija': '/movies/franchise/Ouija',
#  'His Dark Materials': '/movies/franchise/His-Dark-Materials',
#  'Man from Snowy River': '/movies/franchise/Man-from-Snowy-River',
#  '3 Ninjas': '/movies/franchise/3-Ninjas',
#  'The Woman in Black': '/movies/franchise/Woman-in-Black-The',
#  'Gods Must Be Crazy': '/movies/franchise/Gods-Must-Be-Crazy',
#  'The Strangers': '/movies/franchise/Strangers-The',
#  'Hostel': '/movies/franchise/Hostel',
#  'Jarhead ': '/movies/franchise/Jarhead',
#  'Tintin': '/movies/franchise/Tintin',
#  'Best Exotic Marigold Hotel': '/movies/franchise/Best-Exotic-Marigold-Hotel',
#  'A Dogâ\x80\x99s Purpose': '/movies/franchise/Dogs-Purpose-A',
#  'Kick-Ass': '/movies/franchise/Kick-Ass',
#  'Iron Eagle': '/movies/franchise/Iron-Eagle',
#  'Soul Food': '/movies/franchise/Soul-Food',
#  'Hills Have Eyes': '/movies/franchise/Hills-Have-Eyes',
#  'Silent Hill': '/movies/franchise/Silent-Hill',
#  'Without a Paddle': '/movies/franchise/Without-a-Paddle',
#  'Candyman': '/movies/franchise/Candyman',
#  'Sinister': '/movies/franchise/Sinister',
#  'Butterfly Effect': '/movies/franchise/Butterfly-Effect',
#  'Happy Death Day': '/movies/franchise/Happy-Death-Day',
#  'Care Bears': '/movies/franchise/Care-Bears',
#  'Street Fighter': '/movies/franchise/Street-Fighter',
#  'Benchwarmers': '/movies/franchise/Benchwarmers',
#  'Hoodwinked': '/movies/franchise/Hoodwinked',
#  'Wallace and Gromit': '/movies/franchise/Wallace-and-Gromit',
#  'Curious George': '/movies/franchise/Curious-George',
#  'Dark Universe': '/movies/franchise/Dark-Universe',
#  'Stomp the Yard': '/movies/franchise/Stomp-the-Yard',
#  "Carlito's Way": '/movies/franchise/Carlitos-Way',
#  'Willard': '/movies/franchise/Willard',
#  'Three Flavours Cornetto Trilogy': '/movies/franchise/Three-Flavours-Cornetto-Trilogy',
#  'White Noise': '/movies/franchise/White-Noise',
#  'Monty Python': '/movies/franchise/Monty-Python',
#  'Elizabeth': '/movies/franchise/Elizabeth',
#  'All Dogs Go To Heaven': '/movies/franchise/All-Dogs-Go-To-Heaven',
#  'Hitman: Agent 47': '/movies/franchise/Hitman-Agent-47',
#  "George A. Romero's Dead Series": '/movies/franchise/George-A-Romeros-Dead-Series',
#  'A Cinderella Story': '/movies/franchise/Cinderella-Story-A',
#  'Lawnmower Man': '/movies/franchise/Lawnmower-Man',
#  'Lost Boys': '/movies/franchise/Lost-Boys',
#  'Big Fat Liar': '/movies/franchise/Big-Fat-Liar',
#  'Happy Feet': '/movies/franchise/Happy-Feet',
#  'House on Haunted Hill': '/movies/franchise/House-on-Haunted-Hill',
#  'Hot Tub Time Machine': '/movies/franchise/Hot-Tub-Time-Machine',
#  'The Sandlot': '/movies/franchise/The-Sandlot',
#  'Darkman': '/movies/franchise/Darkman',
#  'House': '/movies/franchise/House',
#  'Fright Night': '/movies/franchise/Fright-Night',
#  'Cop and a Half': '/movies/franchise/Cop-and-a-Half',
#  'Air Bud': '/movies/franchise/Air-Bud',
#  'Haunting in Connecticut': '/movies/franchise/Haunting-in-Connecticut',
#  '47 Meters Down': '/movies/franchise/47-Meters-Down',
#  'Boogeyman': '/movies/franchise/Boogeyman',
#  'The Last Exorcism': '/movies/franchise/Last-Exorcism-The',
#  'A Haunted House': '/movies/franchise/Haunted-House-A',
#  'Project X': '/movies/franchise/Project-X',
#  'The Thing': '/movies/franchise/Thing-The',
#  'Baby Geniuses': '/movies/franchise/Baby-Geniuses',
#  'Angel': '/movies/franchise/Angel',
#  'Super Troopers': '/movies/franchise/Super-Troopers',
#  'Punisher': '/movies/franchise/Punisher',
#  'The Howling': '/movies/franchise/Howling-The',
#  'You Got Served': '/movies/franchise/You-Got-Served',
#  'Wild Things': '/movies/franchise/Wild-Things',
#  'Return of the Living Dead': '/movies/franchise/Return-of-the-Living-Dead',
#  'Lake Placid': '/movies/franchise/Lake-Placid',
#  'Viva Pedro Box': '/movies/franchise/Viva-Pedro-Box',
#  'VeggieTales': '/movies/franchise/VeggieTales',
#  'Johnny English': '/movies/franchise/Johnny-English',
#  'The Mechanic': '/movies/franchise/Mechanic-The',
#  'Tales from the Crypt': '/movies/franchise/Tales-from-the-Crypt',
#  'Crank': '/movies/franchise/Crank',
#  'Delta Force': '/movies/franchise/Delta-Force',
#  'Children of the Corn': '/movies/franchise/Children-of-the-Corn',
#  'Dracula 2000': '/movies/franchise/Dracula-2000',
#  'Prom Night': '/movies/franchise/Prom-Night',
#  'The Art of War': '/movies/franchise/The-Art-of-War',
#  'Mimic': '/movies/franchise/Mimic',
#  'Ninja': '/movies/franchise/Ninja',
#  'The Boy': '/movies/franchise/Boy-The',
#  'Allan Quatermain': '/movies/franchise/Allan-Quatermain',
#  'Max': '/movies/franchise/Max',
#  'Death Race': '/movies/franchise/Death-Race',
#  'Johnson Family': '/movies/franchise/Johnson-Family',
#  'Honey': '/movies/franchise/Honey',
#  'Open Water': '/movies/franchise/Open-Water',
#  'Unfriended': '/movies/franchise/Unfriended',
#  'Joe Dirt': '/movies/franchise/Joe-Dirt',
#  'House of 1,000 Corpses': '/movies/franchise/House-of-1000-Corpses',
#  'Gettysburg': '/movies/franchise/Gettysburg',
#  'Sniper': '/movies/franchise/Sniper',
#  'Clerks': '/movies/franchise/Clerks',
#  'Quarantine': '/movies/franchise/Quarantine',
#  'Cirque du Soleil': '/movies/franchise/Cirque-du-Soleil',
#  'Machete': '/movies/franchise/Machete',
#  'Van Wilder': '/movies/franchise/Van-Wilder',
#  'American Ninja': '/movies/franchise/American-Ninja',
#  'Dragon Ball Z': '/movies/franchise/Dragon-Ball-Z',
#  'Critters': '/movies/franchise/Critters',
#  'Space Chimps': '/movies/franchise/Space-Chimps',
#  'An Inconvenient Truth': '/movies/franchise/Inconvenient-Truth-An',
#  'Trainspotting': '/movies/franchise/Trainspotting',
#  'Tremors': '/movies/franchise/Tremors',
#  'Kickboxer': '/movies/franchise/Kickboxer',
#  'Joy Ride': '/movies/franchise/Joy-Ride',
#  'Beastmaster': '/movies/franchise/Beastmaster',
#  'Gate': '/movies/franchise/Gate',
#  'Big Lebowski': '/movies/franchise/Big-Lebowski',
#  'Omega Code': '/movies/franchise/Omega-Code',
#  'Cabin Fever': '/movies/franchise/Cabin-Fever',
#  'Millenium': '/movies/franchise/Millenium',
#  'Never Back Down': '/movies/franchise/Never-Back-Down',
#  'Academy Award Short Film Nominations': '/movies/franchise/Academy-Award-Short-Film-Nominations',
#  'Flicka': '/movies/franchise/Flicka',
#  'Center Stage': '/movies/franchise/Center-Stage',
#  'Alpha and Omega': '/movies/franchise/Alpha-and-Omega',
#  'Before Sunrise': '/movies/franchise/Before-Sunrise',
#  'Pulse': '/movies/franchise/Pulse',
#  'Escape Plan': '/movies/franchise/Escape-Plan',
#  'Warlock': '/movies/franchise/Warlock',
#  'Bloodsport': '/movies/franchise/Bloodsport',
#  'Exterminator': '/movies/franchise/Exterminator',
#  'Baahubali': '/movies/franchise/Baahubali',
#  'The Marine': '/movies/franchise/The-Marine',
#  'Dungeons & Dragons': '/movies/franchise/Dungeons-and-Dragons',
#  'Vacancy': '/movies/franchise/Vacancy',
#  'Wild Orchid': '/movies/franchise/Wild-Orchid',
#  'Skyline': '/movies/franchise/Skyline',
#  'Class of 1984': '/movies/franchise/Class-of-1984',
#  'Far From Home': '/movies/franchise/Far-From-Home',
#  'Leprechaun': '/movies/franchise/Leprechaun',
#  'Pure Country': '/movies/franchise/Pure-Country',
#  'Wrong Turn': '/movies/franchise/Wrong-Turn',
#  'Waiting': '/movies/franchise/Waiting',
#  'Wolf Creek': '/movies/franchise/Wolf-Creek',
#  'American Girl': '/movies/franchise/American-Girl',
#  'Swan Princess': '/movies/franchise/Swan-Princess',
#  'Philadelphia Experiment': '/movies/franchise/Philadelphia-Experiment',
#  'No Manches Frida': '/movies/franchise/No-Manches-Frida',
#  'Les Boys': '/movies/franchise/Les-Boys',
#  "Happily N'Ever After": '/movies/franchise/Happily-Never-After',
#  'Shaun the Sheep': '/movies/franchise/Shaun-the-Sheep',
#  'See No Evil': '/movies/franchise/See-No-Evil',
#  'Arthur and the Minimoys': '/movies/franchise/Arthur-and-the-Minimoys',
#  'Smoke': '/movies/franchise/Smoke',
#  'Undisputed': '/movies/franchise/Undisputed',
#  'My Hero Academia': '/movies/franchise/My-Hero-Academia',
#  'Belly': '/movies/franchise/Belly',
#  'Norm of the North': '/movies/franchise/Norm-of-the-North',
#  'The Man With The Iron Fists': '/movies/franchise/Man-With-The-Iron-Fists-The',
#  'Best of the Best': '/movies/franchise/Best-of-the-Best',
#  'The Collector': '/movies/franchise/Collector-The',
#  'Molly Hartley': '/movies/franchise/Molly-Hartley',
#  'Tom yum goong': '/movies/franchise/Tom-yum-goong',
#  'What the Bleep': '/movies/franchise/What-the-Bleep',
#  'Phantasm': '/movies/franchise/Phantasm',
#  'Trois Couleurs': '/movies/franchise/Trois-Couleurs',
#  '12 Rounds': '/movies/franchise/12-Rounds',
#  'My Little Pony': '/movies/franchise/My-Little-Pony',
#  'Bratz': '/movies/franchise/Bratz',
#  'Dhoom': '/movies/franchise/Dhoom',
#  'Buena Vista Social Club': '/movies/franchise/Buena-Vista-Social-Club',
#  'Boondock Saints': '/movies/franchise/Boondock-Saints',
#  'Jean de Florette': '/movies/franchise/Jean-de-Florette',
#  'City of God': '/movies/franchise/City-of-God',
#  'Trailer Park Boys': '/movies/franchise/Trailer-Park-Boys',
#  'Atlas Shrugged': '/movies/franchise/Atlas-Shrugged',
#  'The Condemned': '/movies/franchise/Condemned-The',
#  'Fire Earth Water': '/movies/franchise/Fire-Earth-Water',
#  'Work and the Glory': '/movies/franchise/Work-and-the-Glory',
#  'Stepfather, The': '/movies/franchise/Stepfather-The',
#  'Ladron que roba a ladron': '/movies/franchise/Ladron-que-roba-a-ladron',
#  'Belle de Jour': '/movies/franchise/Belle-de-Jour',
#  'Cities of Love': '/movies/franchise/Cities-of-Love',
#  'Serbuan maut': '/movies/franchise/Serbuan-maut',
#  'Ip Man': '/movies/franchise/Ip-Man',
#  'Left Behind': '/movies/franchise/Left-Behind',
#  'The Snowman': '/movies/franchise/Snowman-The',
#  'The Trip': '/movies/franchise/Trip-The',
#  'Ong-Bak': '/movies/franchise/Ong-Bak',
#  'Goal': '/movies/franchise/Goal',
#  'In The Name of the King': '/movies/franchise/In-The-Name-of-the-King',
#  'Elvis Gratton': '/movies/franchise/Elvis-Gratton',
#  'No Retreat, No Surrender': '/movies/franchise/No-Retreat-No-Surrender',
#  'State Property': '/movies/franchise/State-Property',
#  'Nitro': '/movies/franchise/Nitro',
#  'Dabangg': '/movies/franchise/Dabangg',
#  '3 Hommes': '/movies/franchise/3-Hommes',
#  'Endless Summer': '/movies/franchise/Endless-Summer',
#  'Goon': '/movies/franchise/Goon',
#  'Cruising Bar': '/movies/franchise/Cruising-Bar',
#  'Aries Films': '/movies/franchise/Aries-Films',
#  '8 Films to Die For': '/movies/franchise/8-Films-to-Die-For',
#  'Asterix': '/movies/franchise/Asterix',
#  'Nueba Yol': '/movies/franchise/Nueba-Yol',
#  'Poison Ivy': '/movies/franchise/Poison-Ivy',
#  'DC Animated Movie Universe': '/movies/franchise/DC-Animated-Movie-Universe',
#  'Tanu Weds Manu': '/movies/franchise/Tanu-Weds-Manu',
#  'Train to Busan': '/movies/franchise/Train-to-Busan',
#  'Laura Cadieux': '/movies/franchise/Laura-Cadieux',
#  'Babar': '/movies/franchise/Babar',
#  'Trois': '/movies/franchise/Trois',
#  'BloodRayne': '/movies/franchise/BloodRayne',
#  'Penitentiary': '/movies/franchise/Penitentiary',
#  'Koi Mil Gaya': '/movies/franchise/Koi-Mil-Gaya',
#  'Dhamaal': '/movies/franchise/Dhamaal',
#  'Henry Fool': '/movies/franchise/Henry-Fool',
#  'Night Watch': '/movies/franchise/Night-Watch',
#  'Baaghi': '/movies/franchise/Baaghi',
#  'Detective Chinatown': '/movies/franchise/Detective-Chinatown',
#  'Ghost in the Shell': '/movies/franchise/Ghost-in-the-Shell',
#  'Dans une galaxie pres de chez vous': '/movies/franchise/Dans-une-galaxie-pres-de-chez-vous',
#  'After': '/movies/franchise/After',
#  'USA - Land of Opportunities': '/movies/franchise/USA-Land-of-Opportunities',
#  'Donnie Darko': '/movies/franchise/Donnie-Darko',
#  '7 Up': '/movies/franchise/7-Up',
#  'Shiloh': '/movies/franchise/Shiloh',
#  'The True North Trilogy': '/movies/franchise/True-North-Trilogy-The',
#  'Saints and Soldiers': '/movies/franchise/Saints-and-Soldiers',
#  'Singham': '/movies/franchise/Singham',
#  'Banlieue 13': '/movies/franchise/Banlieue-13',
#  'Jolly LLB': '/movies/franchise/Jolly-LLB',
#  'Restrepo': '/movies/franchise/Restrepo',
#  'Visiteurs': '/movies/franchise/Visiteurs',
#  'Ren zai jiong tu Tai jiong': '/movies/franchise/Ren-zai-jiong-tu-Tai-jiong',
#  'Boys Life': '/movies/franchise/Boys-Life',
#  'Vengeance Trilogy': '/movies/franchise/Vengeance-Trilogy',
#  'Superfly': '/movies/franchise/Superfly',
#  'Sarkar': '/movies/franchise/Sarkar',
#  'Epic Stories of the Bible': '/movies/franchise/Epic-Stories-of-the-Bible',
#  'Nymphomaniac': '/movies/franchise/Nymphomaniac',
#  'Taxi': '/movies/franchise/Taxi',
#  'ABCD': '/movies/franchise/ABCD',
#  'Souvenir': '/movies/franchise/Souvenir',
#  'Cremaster': '/movies/franchise/Cremaster',
#  'Generation Iron': '/movies/franchise/Generation-Iron',
#  'Cube': '/movies/franchise/Cube',
#  'Cage aux Folles': '/movies/franchise/Cage-aux-Folles',
#  'Journey to the West': '/movies/franchise/Journey-to-the-West',
#  'Detective Dee': '/movies/franchise/Detective-Dee',
#  'The Spanish Apartment': '/movies/franchise/Spanish-Apartment-The',
#  'Ex Files': '/movies/franchise/Ex-Files',
#  'Student of the Year': '/movies/franchise/Student-of-the-Year',
#  'Red Cliff': '/movies/franchise/Red-Cliff',
#  'The Monkey King': '/movies/franchise/Monkey-King-The',
#  'Zhuo yao ji (Monster Hunt)': '/movies/franchise/Zhuo-yao-ji-(Monster-Hunt)',
#  'The Act of Killing': '/movies/franchise/Act-of-Killing-The',
#  'Ai Weiwei': '/movies/franchise/Ai-Weiwei',
#  'Cold War': '/movies/franchise/Cold-War',
#  'Bhoothnath': '/movies/franchise/Bhoothnath',
#  'On Any Sunday': '/movies/franchise/On-Any-Sunday',
#  'Attack on Titan': '/movies/franchise/Attack-on-Titan',
#  'SLC Punk': '/movies/franchise/SLC-Punk',
#  'Seven Up!': '/movies/franchise/Seven-Up',
#  'Swamp Thing': '/movies/franchise/Swamp-Thing',
#  'Apu Trilogy': '/movies/franchise/Apu-Trilogy',
#  'Golmaal': '/movies/franchise/Golmaal',
#  'The Human Centipede': '/movies/franchise/Human-Centipede-The',
#  'OSS 117': '/movies/franchise/OSS-117',
#  'The Red Riding Trilogy': '/movies/franchise/Red-Riding-Trilogy-The',
#  'Hatchet': '/movies/franchise/Hatchet',
#  'In Search of': '/movies/franchise/In-Search-of',
#  'True to the Game': '/movies/franchise/True-to-the-Game',
#  'Herb and Dorothy': '/movies/franchise/Herb-and-Dorothy',
#  'Gekijo ban Naruto': '/movies/franchise/Gekijo-ban-Naruto',
#  'Tai Chi Zero': '/movies/franchise/Tai-Chi-Zero',
#  'Monsters': '/movies/franchise/Monsters',
#  'Eating Out': '/movies/franchise/Eating-Out',
#  'Evangelion': '/movies/franchise/Evangelion',
#  'Seasons Quartet': '/movies/franchise/Seasons-Quartet',
#  'Snabba Cash': '/movies/franchise/Snabba-Cash',
#  'Fengshen Cinematic Universe': '/movies/franchise/Fengshen-Cinematic-Universe',
#  'Malevolence': '/movies/franchise/Malevolence',
#  'BÃ¸lgen': '/movies/franchise/Bolgen',
#  'Appurushido': '/movies/franchise/Appurushido',
#  'Somm': '/movies/franchise/Somm',
#  'On the Run': '/movies/franchise/On-the-Run',
#  'Munde U.K. De': '/movies/franchise/Munde-U-K-De',
#  'V/H/S': '/movies/franchise/V-H-S',
#  'Fukrey': '/movies/franchise/Fukrey',
#  'Lupin III': '/movies/franchise/Lupin-the-Third',
#  "Cowgirls n' Angels": '/movies/franchise/Cowgirls-n-Angels',
#  'Another Gay Movie': '/movies/franchise/Another-Gay-Movie',
#  'Infernal Affairs': '/movies/franchise/Infernal-Affairs',
#  'America the Beautiful': '/movies/franchise/America-the-Beautiful',
#  'I Spit on Your Grave': '/movies/franchise/I-Spit-on-Your-Grave',
#  'Evil Bong': '/movies/franchise/Evil-Bong',
#  'Detective K': '/movies/franchise/Detective-K',
#  'Dod sno': '/movies/franchise/Dod-sno',
#  'Feast': '/movies/franchise/Feast',
#  'Hak Se Wui': '/movies/franchise/Hak-Se-Wui',
#  'Three Mothers': '/movies/franchise/Three-Mothers',
#  'Tiger & Bunny': '/movies/franchise/Tiger-and-Bunny',
#  'San Francisco Opera Cinemacasts 2007': '/movies/franchise/San-Francisco-Opera-Cinemacasts',
#  'Outrage': '/movies/franchise/Outrage',
#  '[REC]': '/movies/franchise/REC',
#  'The Inbetweeners': '/movies/franchise/Inbetweeners-The',
#  'Stake Land': '/movies/franchise/Stake-Land',
#  'Klovn': '/movies/franchise/Klovn',
#  'Girls (China)': '/movies/franchise/Girls-(China)',
#  'Gasland': '/movies/franchise/Gasland',
#  "ABC's of Death": '/movies/franchise/ABC-s-of-Death',
#  'As Mil e Uma Noites': '/movies/franchise/As-Mil-e-Uma-Noites',
#  'Django': '/movies/franchise/Django',
#  "St. Trinian's": '/movies/franchise/St-Trinian-s',
#  'The Wedding Party': '/movies/franchise/Wedding-Party-The',
#  'Tomorrow, When the War Began': '/movies/franchise/Tomorrow-When-the-War-Began',
#  'Donald Strachey': '/movies/franchise/Donald-Strachey',
#  "Nuke 'Em High": '/movies/franchise/Nuke-Em-High',
#  'Contracted': '/movies/franchise/Contracted',
#  'Hayride': '/movies/franchise/Hayride',
#  'Barbie': '/movies/franchise/Barbie',
#  'Air Buddies': '/movies/franchise/Air-Buddies',
#  'Boonie Bears': '/movies/franchise/Boonie-Bears',
#  'Monster High': '/movies/franchise/Monster-High',
#  'Justice League': '/movies/franchise/Justice-League',
#  'Tinker Bell': '/movies/franchise/Tinker-Bell',
#  'Mickey Mouse': '/movies/franchise/Mickey-Mouse',
#  'Sharknado': '/movies/franchise/Sharknado',
#  'Strawberry Shortcake': '/movies/franchise/Strawberry-Shortcake',
#  'Doraemon': '/movies/franchise/Doraemon',
#  'Desu Noto': '/movies/franchise/Desu-Noto',
#  'RiffTrax Live': '/movies/franchise/RiffTrax-Live',
#  'Sister Street Fighter': '/movies/franchise/Sister-Street-Fighter',
#  'Futurama': '/movies/franchise/Futurama',
#  'Pororo': '/movies/franchise/Pororo',
#  'Shopkins': '/movies/franchise/Shopkins',
#  'Crayon Shin Chan': '/movies/franchise/Crayon-Shin-Chan',
#  'Ivan Tsarevich i Seryy Volk': '/movies/franchise/Ivan-Tsarevich-i-Seryy-Volk',
#  'Argentoâ\x80\x99s Animal Trilogy': '/movies/franchise/Argentos-Animal-Trilogy',
#  'Basket Case': '/movies/franchise/Basket-Case',
#  'Nativity': '/movies/franchise/Nativity',
#  'Thomas and Friends': '/movies/franchise/Thomas-and-Friends',
#  'Rogue Warfare': '/movies/franchise/Rogue-Warfare',
#  'Smetto Quando Voglio': '/movies/franchise/Smetto-Quando-Voglio',
#  'Police Story': '/movies/franchise/Police-Story',
#  'Masked Rider': '/movies/franchise/Masked-Rider',
#  'The Toxic Avenger': '/movies/franchise/Toxic-Avenger-The',
#  'Santa Buddies': '/movies/franchise/Santa-Buddies',
#  'Sleepaway Camp': '/movies/franchise/Sleepaway-Camp',
#  'Descendants': '/movies/franchise/Descendants',
#  'Belle et Sebastien': '/movies/franchise/Belle-et-Sebastien',
#  'All Hallows Eve': '/movies/franchise/All-Hallows-Eve',
#  'Bad Ass': '/movies/franchise/Bad-Ass',
#  'Fack ju GÃ¶hte': '/movies/franchise/Fack-ju-Gohte',
#  'Doctor Who': '/movies/franchise/Doctor-Who',
#  'Fred Figglehorn': '/movies/franchise/Fred-Figglehorn',
#  'Uncle Kent': '/movies/franchise/Uncle-Kent',
#  'Pumping Iron': '/movies/franchise/Pumping-Iron',
#  'MSG The Messenger of God': '/movies/franchise/MSG-The-Messenger-of-God',
#  'Kiseijuu': '/movies/franchise/Kiseijuu',
#  'John Clark': '/movies/franchise/John-Clark',
#  'The Dead': '/movies/franchise/Dead-The',
#  'Phineas and Ferb': '/movies/franchise/Phineas-and-Ferb',
#  'I Am Vengeance': '/movies/franchise/I-Am-Vengeance',
#  'Wilden Kerle': '/movies/franchise/Wilden-Kerle',
#  'The Man From Macau': '/movies/franchise/Man-From-Macau-The',
#  'Si da ming bu': '/movies/franchise/Si-da-ming-bu',
#  'When Calls the Heart': '/movies/franchise/When-Calls-the-Heart',
#  'The Hamiltons': '/movies/franchise/Hamiltons-The',
#  'Ryanverse': '/movies/franchise/Ryanverse',
#  'Wolfcop': '/movies/franchise/Wolfcop',
#  'Fireangels': '/movies/franchise/Fireangels',
#  'Best F(r)iends': '/movies/franchise/Best-F(r)iends',
#  'Tiny Times': '/movies/franchise/Tiny-Times',
#  'The Woman': '/movies/franchise/Woman-The',
#  'A Bread Factory': '/movies/franchise/Bread-Factory-A',
#  'Arn': '/movies/franchise/Arn',
#  'Rise of the Footsoldier': '/movies/franchise/Rise-of-the-Footsoldier',
#  'Debt Collector': '/movies/franchise/Debt-Collector',
#  'Crossword Mysteries': '/movies/franchise/Crossword-Mysteries',
#  'Mortadelo y Filemon': '/movies/franchise/Mortadelo-y-Filemon',
#  'Spanish Affair': '/movies/franchise/Spanish-Affair',
#  'Tom and Jerry': '/movies/franchise/Tom-and-Jerry',
#  'When Love Happens': '/movies/franchise/When-Love-Happens',
#  'Detective Conan': '/movies/franchise/Detective-Conan',
#  'Celtic Woman': '/movies/franchise/Celtic-Woman',
#  'Paw Patrol': '/movies/franchise/Paw-Patrol',
#  'The Pact': '/movies/franchise/Pact-The',
#  '13 Cameras': '/movies/franchise/13-Cameras',
#  'Marfa Girl': '/movies/franchise/Marfa-Girl',
#  'Antboy': '/movies/franchise/Antboy',
#  'A Godwink Christmas': '/movies/franchise/Godwink-Christmas-A',
#  'What Would Jesus Do?': '/movies/franchise/What-Would-Jesus-Do',
#  'Top Cat': '/movies/franchise/Top-Cat',
#  'Always': '/movies/franchise/Always-(Japan)',
#  'Teen Beach Movie': '/movies/franchise/Teen-Beach-Movie',
#  'The Kissing Booth': '/movies/franchise/Kissing-Booth-The',
#  'Vacanze': '/movies/franchise/Vacanze',
#  'Torrente': '/movies/franchise/Torrente',
#  'Maniac Cop': '/movies/franchise/Maniac-Cop',
#  'Bright': '/movies/franchise/Bright',
#  'Snezhnaya koroleva': '/movies/franchise/Snezhnaya-koroleva',
#  'exhibition on screen': '/movies/franchise/exhibition-on-screen',
#  'Rest Stop': '/movies/franchise/Rest-Stop',
#  'Kidulthood': '/movies/franchise/Kidulthood',
#  'Gangster Ka': '/movies/franchise/Gangster-Ka',
#  'American Psycho': '/movies/franchise/American-Psycho',
#  'Pyaar Ka Punchnama': '/movies/franchise/Pyaar-Ka-Punchnama',
#  'Help': '/movies/franchise/Help',
#  'The Princess Switch': '/movies/franchise/Princess-Switch-The',
#  'Coconut the Little Dragon': '/movies/franchise/Coconut-the-Little-Dragon',
#  'Le cÅ\x93ur des hommes': '/movies/franchise/Coeur-des-hommes-Les',
#  'Digimon': '/movies/franchise/Digimon',
#  'azem': '/movies/franchise/azem',
#  'Monochrome': '/movies/franchise/Monochrome',
#  'Bhoot': '/movies/franchise/Bhoot',
#  'Lighting Dindin': '/movies/franchise/Lighting-Dindin',
#  'Kitaro': '/movies/franchise/Kitaro',
#  '7 Zwerge': '/movies/franchise/7-Zwerge',
#  'Daan gyun naam Yu': '/movies/franchise/Daan-gyun-naam-Yu',
#  'Signed, Sealed, Delivered': '/movies/franchise/Signed-Sealed-Delivered',
#  'Dino Dana': '/movies/franchise/Dino-Dana',
#  'Ironiya Sudby': '/movies/franchise/Ironiya-Sudby',
#  'Greenstreet Hooligans': '/movies/franchise/Greenstreet-Hooligans',
#  'Blind Dead': '/movies/franchise/Blind-Dead',
#  'Ironclad': '/movies/franchise/Ironclad',
#  'Biggest Loser': '/movies/franchise/Biggest-Loser',
#  'The Craft': '/movies/franchise/Craft-The',
#  'Z-O-M-B-I-E-S': '/movies/franchise/Z-O-M-B-I-E-S',
#  'Rod Allbright Alien Adventures': '/movies/franchise/Rod-Allbright-Alien-Adventures',
#  'Freeway': '/movies/franchise/Freeway',
#  'The Locator': '/movies/franchise/Locator-The',
#  'Kocan Kadar Konus': '/movies/franchise/Kocan-Kadar-Konus',
#  'Weiner Dog': '/movies/franchise/Weiner-Dog',
#  'Howling': '/movies/franchise/Howling',
#  'Redwood Massacre': '/movies/franchise/Redwood-Massacre',
#  'Vaxxed': '/movies/franchise/Vaxxed',
#  'Attack of the Killer Tomatoes': '/movies/franchise/Attack-of-the-Killer-Tomatoes',
#  'Yokai Watch': '/movies/franchise/Yokai-Watch',
#  'Twentieth Century Boys': '/movies/franchise/Twentieth-Century-Boys',
#  'Father There is Only One': '/movies/franchise/Padre-no-hay-mas-que-uno',
#  'The Devilâ\x80\x99s Rejects': '/movies/franchise/Devils-Rejects-The',
#  'The Munsters': '/movies/franchise/Munsters-The',
#  'Maruko': '/movies/franchise/Maruko',
#  'Against the Wild': '/movies/franchise/Against-the-Wild',
#  'A Few Best Men': '/movies/franchise/Few-Best-Men-A',
#  'Christmas in Evergreen': '/movies/franchise/Christmas-in-Evergreen',
#  'L.E.T.H.A.L.': '/movies/franchise/L-E-T-H-A-L',
#  'The Walking Dead': '/movies/franchise/Walking-Dead-The',
#  'Jillian Michaels Fitness': '/movies/franchise/Jillian-Michaels-Fitness',
#  'The Christmas Chronicles': '/movies/franchise/Christmas-Chronicles-The',
#  'Troublesome Night': '/movies/franchise/Troublesome-Night',
#  'Meitantei Conan': '/movies/franchise/Meitantei-Conan',
#  'Dragons Nest': '/movies/franchise/Dragons-Nest',
#  'Cin Bebek': '/movies/franchise/Cin-Bebek',
#  'Tales From Sanctuary City': '/movies/franchise/Tales-From-Sanctuary-City',
#  'After Porn Ends': '/movies/franchise/After-Porn-Ends',
#  'Iron Sky': '/movies/franchise/Iron-Sky',
#  'Escape Room': '/movies/franchise/Escape-Room',
#  'The Invoking': '/movies/franchise/Invoking-The',
#  'Chicken Run': '/movies/franchise/Chicken-Run',
#  'Boy s tenyu': '/movies/franchise/Boy-s-tenyu',
#  'Tanguy': '/movies/franchise/Tanguy',
#  '10/31': '/movies/franchise/10-31',
#  'Intrigo': '/movies/franchise/Intrigo',
#  'Brightheart': '/movies/franchise/Brightheart',
#  'Wild Geese': '/movies/franchise/Wild-Geese',
#  'Get Smart': '/movies/franchise/Get-Smart',
#  'Pripara': '/movies/franchise/Pripara',
#  'Winx Club': '/movies/franchise/Winx-Club',
#  'Ultraman': '/movies/franchise/Ultraman',
#  'Qian bu gou yong': '/movies/franchise/Qian-bu-gou-yong',
#  'Frankenstein': '/movies/franchise/Frankenstein',
#  'King of Prism': '/movies/franchise/King-of-Prism',
#  'Twitches': '/movies/franchise/Twitches',
#  '10 Minute Solution': '/movies/franchise/10-Minute-Solution',
#  'Yolki': '/movies/franchise/Yolki',
#  'Shakugan no Shana': '/movies/franchise/Shakugan-no-Shana',
#  'Les BronzÃ©s': '/movies/franchise/Bronzes-Les',
#  'Mirror Mirror': '/movies/franchise/Mirror-Mirror',
#  'Lalaloopsy': '/movies/franchise/Lalaloopsy',
#  'Tarapaty': '/movies/franchise/Tarapaty',
#  'The Librarian': '/movies/franchise/Librarian-The',
#  'Bulletproof': '/movies/franchise/Bulletproof',
#  "Carl Bessai's Relatives": '/movies/franchise/Carl-Bessai-s-Relatives',
#  'Action Six Pack': '/movies/franchise/Action-Six-Pack',
#  'Les randonneurs': '/movies/franchise/randonneurs-Les',
#  'Jay and Silent Bob': '/movies/franchise/Jay-and-Silent-Bob'}

# %%
#testing set

# Initialize limit  
N = 3
    
# Using items() + list slicing  
# Get first K items in dictionary  
out = dict(list(franchiselinks.items())[0: N])

# %%
tempstuff = scraper(out, tempset)
# Out:
# Item 1 / 3 - Marvel Cinematic Universe
# Item 2 / 3 - Star Wars
# Item 3 / 3 - James Bond
# 0.11883333333333333 minutes elapsed
# 2.38 seconds per item

# %%
tempstuff
# Out:
# {'franchise': ['Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Marvel Cinematic Universe',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'Star Wars',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond',
#   'James Bond'],
#  'movie': ['May 6, 2022',
#   'Black Panther II',
#   'Nov 5, 2021',
#   'Eternals',
#   'Nov 5, 2021',
#   'Untitled Spider-Man: Far Fr…',
#   'Jul 9, 2021',
#   'Shang Chi and the Legend of…',
#   'May 7, 2021',
#   'Black Widow',
#   'Dec 31, 2020',
#   'Spider-Man 4: Fan Film',
#   'Jul 2, 2019',
#   'Spider-Man: Far From Home',
#   'Apr 26, 2019',
#   'Avengers: Endgame',
#   'Mar 8, 2019',
#   'Captain Marvel',
#   'Jul 6, 2018',
#   'Ant-Man and the Wasp',
#   'Apr 27, 2018',
#   'Avengers: Infinity War',
#   'Feb 16, 2018',
#   'Black Panther',
#   'Nov 3, 2017',
#   'Thor: Ragnarok',
#   'Jul 7, 2017',
#   'Spider-Man: Homecoming',
#   'May 5, 2017',
#   'Guardians of the Galaxy Vol 2',
#   'Nov 4, 2016',
#   'Doctor Strange',
#   'May 6, 2016',
#   'Captain America: Civil War',
#   'Jul 17, 2015',
#   'Ant-Man',
#   'May 1, 2015',
#   'Avengers: Age of Ultron',
#   'Aug 1, 2014',
#   'Guardians of the Galaxy',
#   'Apr 4, 2014',
#   'Captain America: The Winter…',
#   'Nov 8, 2013',
#   'Thor: The Dark World',
#   'May 3, 2013',
#   'Iron Man 3',
#   'May 4, 2012',
#   'The Avengers',
#   'Jul 22, 2011',
#   'Captain America: The First …',
#   'May 6, 2011',
#   'Thor',
#   'May 7, 2010',
#   'Iron Man 2',
#   'Jun 13, 2008',
#   'The Incredible Hulk',
#   'May 2, 2008',
#   'Iron Man',
#   'Dec 17, 2027',
#   'Untitled Star Wars Movie',
#   'Dec 19, 2025',
#   'Untitled Star Wars Movie',
#   'Dec 22, 2023',
#   'Untitled Star Wars Movie',
#   'Dec 20, 2019',
#   'Star Wars: The Rise of Skyw…',
#   'May 25, 2018',
#   'Solo: A Star Wars Story',
#   'Dec 15, 2017',
#   'Star Wars Ep. VIII: The Las…',
#   'Dec 16, 2016',
#   'Rogue One: A Star Wars Story',
#   'Dec 18, 2015',
#   'Star Wars Ep. VII: The Forc…',
#   'Aug 15, 2008',
#   'Star Wars: The Clone Wars',
#   'May 19, 2005',
#   'Star Wars Ep. III: Revenge …',
#   'May 16, 2002',
#   'Star Wars Ep. II: Attack of…',
#   'May 19, 1999',
#   'Star Wars Ep. I: The Phanto…',
#   'May 25, 1983',
#   'Star Wars Ep. VI: Return of…',
#   'May 21, 1980',
#   'Star Wars Ep. V: The Empire…',
#   'Star Wars Ep. IV: A New Hope',
#   'Apr 2, 2021',
#   'No Time to Die',
#   'Nov 6, 2015',
#   'Spectre',
#   'Nov 8, 2012',
#   'Skyfall',
#   'Nov 14, 2008',
#   'Quantum of Solace',
#   'Nov 17, 2006',
#   'Casino Royale',
#   'Nov 22, 2002',
#   'Die Another Day',
#   'Nov 19, 1999',
#   'The World is Not Enough',
#   'Dec 19, 1997',
#   'Tomorrow Never Dies',
#   'Nov 17, 1995',
#   'Goldeneye',
#   'Jul 14, 1989',
#   'Licence to Kill',
#   'Jul 31, 1987',
#   'The Living Daylights',
#   'May 24, 1985',
#   'A View to a Kill',
#   'Oct 7, 1983',
#   'Never Say Never Again',
#   'Jun 10, 1983',
#   'Octopussy',
#   'Jun 26, 1981',
#   'For Your Eyes Only',
#   'Jun 29, 1979',
#   'Moonraker',
#   'Jul 13, 1977',
#   'The Spy Who Loved Me',
#   'The Man with the Golden Gun',
#   'Live and Let Die',
#   'Diamonds Are Forever',
#   "On Her Majesty's Secret Ser…",
#   'You Only Live Twice',
#   'Casino Royale',
#   'Thunderball',
#   'Goldfinger',
#   'From Russia With Love',
#   'Dr. No']}

# %%
franchises = pd.DataFrame(tempstuff)
franchises
# Out:
#                      franchise                  movie
# 0    Marvel Cinematic Universe            May 6, 2022
# 1    Marvel Cinematic Universe       Black Panther II
# 2    Marvel Cinematic Universe            Nov 5, 2021
# 3    Marvel Cinematic Universe               Eternals
# 4    Marvel Cinematic Universe            Nov 5, 2021
# ..                         ...                    ...
# 126                 James Bond          Casino Royale
# 127                 James Bond            Thunderball
# 128                 James Bond             Goldfinger
# 129                 James Bond  From Russia With Love
# 130                 James Bond                 Dr. No
#
# [131 rows x 2 columns]

# %% [markdown]
# # The Big Scrape
#
# We're ready to do the big scrape!
# We'll break our frame of 10,000 entries into 10 smaller ones in case of any errors.

# %%
franchiselinks = {}

# %%
movietitles = {'franchise' : [], 'movie' : []}

# %%
get_franchises()

# %%
# Initialize limit  
N = 800
    
# Using items() + list slicing  
# Get first K items in dictionary  
listof800 = dict(list(franchiselinks.items())[0: N])

# %%
movietitles = scraper(listof800, movietitles)
# Out:
# Item 1 / 800 - Marvel Cinematic Universe

# %%
movietitles

# %%
franchises = pd.DataFrame(movietitles)
franchises

# %%
# Setting the title as the index
#franchises.set_index('id', inplace=True)

# %% [markdown]
# # Data Export

# %%
#exporting the dataframe to a csv
#franchises.to_csv('api_data/franchises_scraped.csv')
